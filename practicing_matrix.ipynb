# %% [markdown]
# <a href="https://colab.research.google.com/github/kanika10-hub/DL_LEARN_LOG/blob/main/practicing_matrix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
revenue=np.array([[180,200,220],[24,36,40],[12,18,20]])

# %%
expenses=np.array([[80,90,100],[10,16,20],[8,10,10]])

# %%
profit=revenue-expenses
profit
# Out:
# array([[100, 110, 120],
#        [ 14,  20,  20],
#        [  4,   8,  10]])

# %% [markdown]
# mutliplication- learning broadcasting

# %%
price=np.array([1,2,3])
units= np.array([[1,2,3],[4,5,6],[5,6,7]])

# %%
price*units
# Out:
# array([[ 1,  4,  9],
#        [ 4, 10, 18],
#        [ 5, 12, 21]])
